# %% [markdown]
# # Part 2: Stochastic Gradient Descent, Momentum, and Adam

# %% [markdown]
# ### For this part of the lab, using the same data and setup as in Part 1, compare how stochastic gradient descent (SGD), SGD with momentum, and ADAM will perform. You are free to write all of the code on your own, or if you prefer, you can fill in the missing sections in the code below.

# %% [markdown]
# ### Start by reusing some of the functions you have coded for Part 1 to compute the hypothesis, the gradient of the cost function, and the cost function. This code will then be used by the next section of the workbook.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

## generate M data points roughly forming a line (noise added)
M = 50
theta_true = torch.Tensor([[0.5], [2]])

X = 10 * torch.rand(M, 2) - 5
X[:, 1] = 1.0

y = torch.mm(X, theta_true) + 0.3 * torch.randn(M, 1)

## hypothesis computes $h_theta$
def hypothesis(theta, X):
    return X @ theta

## grad_cost_func computes the gradient of J for linear regression given J is the MSE 
def grad_cost_func(theta, X, y): 
    return (X.t() @ (X@theta - y)) / X.size(0)

## cost_func computes the cost function J
def cost_func(theta, X, y): 
    return 0.5 * (torch.sum((X @ theta - y) ** 2, 0))/ X.size(0)

# %% [markdown]
# ## Now we'd like to compare how stochastic gradient descent (SGD), SGD with momentum, and ADAM will run over weight updates. Complete the defined functions below and make sure to add the parameters which may need to be passed into the functions as well. Plot the weight updates over the contour plot using varying colours. Note, for clarity, you may only want to plot some of the updates.

# %%
## The weight update computed using the ADAM optimisation algorithm
def weightupdate_adam(count, X, y):
    N = count
    p = X.size(1)
    M = X.size(0)
    theta = torch.Tensor(p,N)
    theta[:,0] = torch.Tensor([2,4])
    v = 0
    s = 0
    for i in range(1,N):
        j = np.floor(np.random.rand(batch_size)*M).astype(int)
        xj = X[j,:]
        yj = y[j,:].reshape(1,-1)
        yPred = xj @ theta[:,i-1].reshape(-1,1)
        dw = torch.sum((yPred - yj.t()) * xj, dim = 0)
        v = beta_1 * v + (1-beta_1) * dw
        v_corr = v / (1 - beta_1 ** i)
        s = beta_2 * s + (1-beta_2) * dw * dw
        s_corr = s / (1 - beta_2 ** i)        
        theta[:,i] =  theta[:,i-1] - alpha * v_corr / torch.sqrt(s_corr)
        
    return theta

## The weight update computed using SGD + momentum
def weightupdate_sgd_momentum(count, X, y):
    N = count
    p = X.size(1)
    M = X.size(0)
    theta = torch.Tensor(p,N)
    theta[:,0] = torch.Tensor([2,4])
    v = 0
    for i in range(1,N):
        j = np.floor(np.random.rand(batch_size)*M).astype(int)
        xj = X[j,:]
        yj = y[j,:].reshape(1,-1)
        yPred = xj @ theta[:,i-1].reshape(-1,1)
        dw = torch.sum((yPred - yj.t()) * xj, dim = 0)
        v = beta_1 * v + (1-beta_1) * dw
        theta[:,i] =  theta[:,i-1] - alpha * v
        
    return theta

## The weight updated computed using SGD
def weigthupdate_sgd(count, X, y):
    N = count
    p = X.size(1)
    M = X.size(0)
    theta = torch.Tensor(p,N)
    theta[:,0] = torch.Tensor([2,4])
    
    for i in range(1,N):
        j = np.floor(np.random.rand(batch_size)*M).astype(int)
        xj = X[j,:]
        yj = y[j,:].reshape(1,-1)
        yPred = xj @ theta[:,i-1].reshape(-1,1)
        dw = torch.sum((yPred - yj.t()) * xj, dim = 0)
        theta[:,i] =  theta[:,i-1] - alpha * dw
        
    return theta

batch_size = 3
N = 400
beta_1 = 0.9
beta_2 = 0.999
alpha = 0.05

# Write the code that will call of the optimisation update functions and compute weight updates for each individual data point over N iterations.

theta_sgd = weigthupdate_sgd(N , X, y).t()
theta_sgd_momentum = weightupdate_sgd_momentum(N , X, y).t()
theta_adam = weightupdate_adam(N , X, y).t()


theta_0_vals = np.linspace(-2,2,100)
theta_1_vals = np.linspace(-8,8,100)
theta = torch.Tensor(len(theta_0_vals),2)

# Compute the value of the cost function, J, over all the thetas in order to plot the contour below.
J = torch.Tensor(len(theta_0_vals),len(theta_1_vals))
for i in range(len(theta_0_vals)):
    for j in range(len(theta_1_vals)):
        this_theta = torch.Tensor(2,1)
        this_theta[0] = theta_0_vals[i]
        this_theta[1] = theta_1_vals[j]
        J[i,j] = cost_func(this_theta, X, y)[0]

xc,yc = np.meshgrid(theta_0_vals, theta_1_vals)
contours = plt.contour(xc, yc, J, 15)

# Now plot the output of SGD, momentum and Adam all on the same plot for comparison
for i in range(N):
    if i%20 == 0:
        plt.scatter(theta_sgd[i,0].numpy(), theta_sgd[i,1].numpy(), color= "r")
        plt.scatter(theta_sgd_momentum[i,0].numpy(), theta_sgd_momentum[i,1].numpy(), color= "b")
        plt.scatter(theta_adam[i,0].numpy(), theta_adam[i,1].numpy(), color= "g")
plt.show()

# %%
theta_adam  # 给adam设置一个比较大的alpha
# Out:
# tensor([[2.0000, 4.0000],
#         [1.9500, 3.9500],
#         [1.9117, 3.9136],
#         [1.8712, 3.8712],
#         [1.8346, 3.8321],
#         [1.7946, 3.7907],
#         [1.7517, 3.7465],
#         [1.7065, 3.7026],
#         [1.6599, 3.6659],
#         [1.6120, 3.6254],
#         [1.5665, 3.5825],
#         [1.5205, 3.5395],
#         [1.4753, 3.4966],
#         [1.4291, 3.4510],
#         [1.3850, 3.4104],
#         [1.3399, 3.3668],
#         [1.2964, 3.3287],
#         [1.2525, 3.2879],
#         [1.2129, 3.2494],
#         [1.1721, 3.2084],
#         [1.1329, 3.1746],
#         [1.0970, 3.1439],
#         [1.0627, 3.1136],
#         [1.0267, 3.0795],
#         [0.9926, 3.0450],
#         [0.9608, 3.0126],
#         [0.9315, 2.9815],
#         [0.9046, 2.9507],
#         [0.8780, 2.9182],
#         [0.8539, 2.8875],
#         [0.8312, 2.8586],
#         [0.8093, 2.8303],
#         [0.7875, 2.8026],
#         [0.7651, 2.7757],
#         [0.7429, 2.7489],
#         [0.7198, 2.7207],
#         [0.6990, 2.6942],
#         [0.6789, 2.6679],
#         [0.6604, 2.6440],
#         [0.6436, 2.6210],
#         [0.6272, 2.5980],
#         [0.6100, 2.5742],
#         [0.5936, 2.5506],
#         [0.5784, 2.5278],
#         [0.5650, 2.5058],
#         [0.5531, 2.4840],
#         [0.5419, 2.4631],
#         [0.5314, 2.4426],
#         [0.5212, 2.4229],
#         [0.5114, 2.4032],
#         [0.5015, 2.3839],
#         [0.4923, 2.3656],
#         [0.4844, 2.3479],
#         [0.4784, 2.3303],
#         [0.4727, 2.3131],
#         [0.4670, 2.2967],
#         [0.4618, 2.2817],
#         [0.4569, 2.2672],
#         [0.4528, 2.2532],
#         [0.4489, 2.2400],
#         [0.4455, 2.2283],
#         [0.4425, 2.2167],
#         [0.4399, 2.2053],
#         [0.4373, 2.1938],
#         [0.4349, 2.1828],
#         [0.4325, 2.1719],
#         [0.4307, 2.1612],
#         [0.4295, 2.1505],
#         [0.4288, 2.1402],
#         [0.4279, 2.1299],
#         [0.4267, 2.1198],
#         [0.4258, 2.1103],
#         [0.4255, 2.0999],
#         [0.4254, 2.0909],
#         [0.4259, 2.0820],
#         [0.4273, 2.0730],
#         [0.4285, 2.0645],
#         [0.4295, 2.0567],
#         [0.4307, 2.0494],
#         [0.4319, 2.0426],
#         [0.4332, 2.0366],
#         [0.4346, 2.0316],
#         [0.4360, 2.0270],
#         [0.4377, 2.0217],
#         [0.4396, 2.0174],
#         [0.4428, 2.0131],
#         [0.4464, 2.0080],
#         [0.4499, 2.0027],
#         [0.4527, 1.9968],
#         [0.4557, 1.9906],
#         [0.4584, 1.9849],
#         [0.4602, 1.9795],
#         [0.4623, 1.9743],
#         [0.4644, 1.9695],
#         [0.4663, 1.9649],
#         [0.4678, 1.9601],
#         [0.4689, 1.9553],
#         [0.4700, 1.9512],
#         [0.4704, 1.9491],
#         [0.4706, 1.9469],
#         [0.4709, 1.9447],
#         [0.4719, 1.9423],
#         [0.4726, 1.9413],
#         [0.4735, 1.9396],
#         [0.4741, 1.9375],
#         [0.4743, 1.9350],
#         [0.4745, 1.9331],
#         [0.4749, 1.9305],
#         [0.4750, 1.9282],
#         [0.4759, 1.9250],
#         [0.4758, 1.9223],
#         [0.4755, 1.9202],
#         [0.4755, 1.9196],
#         [0.4754, 1.9195],
#         [0.4747, 1.9209],
#         [0.4738, 1.9214],
#         [0.4732, 1.9230],
#         [0.4722, 1.9254],
#         [0.4713, 1.9279],
#         [0.4701, 1.9303],
#         [0.4687, 1.9330],
#         [0.4684, 1.9339],
#         [0.4679, 1.9352],
#         [0.4672, 1.9364],
#         [0.4670, 1.9373],
#         [0.4668, 1.9379],
#         [0.4669, 1.9378],
#         [0.4671, 1.9380],
#         [0.4668, 1.9376],
#         [0.4671, 1.9387],
#         [0.4673, 1.9398],
#         [0.4678, 1.9411],
#         [0.4683, 1.9426],
#         [0.4699, 1.9424],
#         [0.4723, 1.9405],
#         [0.4738, 1.9394],
#         [0.4759, 1.9374],
#         [0.4777, 1.9357],
#         [0.4790, 1.9333],
#         [0.4793, 1.9302],
#         [0.4791, 1.9278],
#         [0.4789, 1.9266],
#         [0.4781, 1.9248],
#         [0.4771, 1.9242],
#         [0.4759, 1.9241],
#         [0.4745, 1.9247],
#         [0.4729, 1.9247],
#         [0.4712, 1.9248],
#         [0.4698, 1.9244],
#         [0.4682, 1.9243],
#         [0.4666, 1.9244],
#         [0.4655, 1.9242],
#         [0.4644, 1.9246],
#         [0.4642, 1.9260],
#         [0.4642, 1.9277],
#         [0.4645, 1.9284],
#         [0.4656, 1.9287],
#         [0.4665, 1.9287],
#         [0.4670, 1.9283],
#         [0.4679, 1.9278],
#         [0.4684, 1.9269],
#         [0.4687, 1.9261],
#         [0.4689, 1.9246],
#         [0.4683, 1.9233],
#         [0.4677, 1.9221],
#         [0.4673, 1.9211],
#         [0.4671, 1.9206],
#         [0.4673, 1.9190],
#         [0.4675, 1.9181],
#         [0.4670, 1.9176],
#         [0.4665, 1.9170],
#         [0.4653, 1.9167],
#         [0.4640, 1.9183],
#         [0.4627, 1.9193],
#         [0.4626, 1.9196],
#         [0.4623, 1.9213],
#         [0.4622, 1.9229],
#         [0.4625, 1.9254],
#         [0.4629, 1.9280],
#         [0.4633, 1.9310],
#         [0.4640, 1.9345],
#         [0.4647, 1.9379],
#         [0.4660, 1.9408],
#         [0.4678, 1.9431],
#         [0.4700, 1.9450],
#         [0.4717, 1.9465],
#         [0.4735, 1.9465],
#         [0.4753, 1.9463],
#         [0.4770, 1.9465],
#         [0.4782, 1.9467],
#         [0.4784, 1.9471],
#         [0.4799, 1.9479],
#         [0.4817, 1.9485],
#         [0.4833, 1.9490],
#         [0.4846, 1.9494],
#         [0.4854, 1.9505],
#         [0.4858, 1.9519],
#         [0.4862, 1.9540],
#         [0.4863, 1.9578],
#         [0.4864, 1.9614],
#         [0.4863, 1.9644],
#         [0.4864, 1.9658],
#         [0.4857, 1.9655],
#         [0.4843, 1.9648],
#         [0.4837, 1.9641],
#         [0.4829, 1.9634],
#         [0.4816, 1.9619],
#         [0.4803, 1.9603],
#         [0.4791, 1.9587],
#         [0.4773, 1.9593],
#         [0.4759, 1.9610],
#         [0.4760, 1.9608],
#         [0.4756, 1.9603],
#         [0.4748, 1.9607],
#         [0.4744, 1.9591],
#         [0.4736, 1.9576],
#         [0.4723, 1.9556],
#         [0.4713, 1.9545],
#         [0.4701, 1.9536],
#         [0.4687, 1.9520],
#         [0.4684, 1.9512],
#         [0.4692, 1.9488],
#         [0.4696, 1.9475],
#         [0.4696, 1.9472],
#         [0.4707, 1.9479],
#         [0.4726, 1.9482],
#         [0.4752, 1.9474],
#         [0.4774, 1.9460],
#         [0.4792, 1.9441],
#         [0.4804, 1.9447],
#         [0.4813, 1.9448],
#         [0.4823, 1.9439],
#         [0.4838, 1.9425],
#         [0.4850, 1.9423],
#         [0.4861, 1.9422],
#         [0.4866, 1.9415],
#         [0.4866, 1.9413],
#         [0.4869, 1.9416],
#         [0.4869, 1.9435],
#         [0.4864, 1.9456],
#         [0.4853, 1.9468],
#         [0.4838, 1.9480],
#         [0.4824, 1.9505],
#         [0.4812, 1.9530],
#         [0.4803, 1.9568],
#         [0.4807, 1.9618],
#         [0.4816, 1.9652],
#         [0.4812, 1.9663],
#         [0.4815, 1.9666],
#         [0.4818, 1.9680],
#         [0.4819, 1.9698],
#         [0.4820, 1.9712],
#         [0.4821, 1.9731],
#         [0.4815, 1.9751],
#         [0.4807, 1.9788],
#         [0.4805, 1.9828],
#         [0.4800, 1.9860],
#         [0.4801, 1.9865],
#         [0.4797, 1.9874],
#         [0.4795, 1.9892],
#         [0.4791, 1.9904],
#         [0.4788, 1.9913],
#         [0.4792, 1.9941],
#         [0.4800, 1.9970],
#         [0.4808, 1.9995],
#         [0.4815, 2.0025],
#         [0.4814, 2.0044],
#         [0.4813, 2.0034],
#         [0.4804, 2.0045],
#         [0.4792, 2.0054],
#         [0.4786, 2.0046],
#         [0.4771, 2.0024],
#         [0.4764, 2.0002],
#         [0.4759, 1.9983],
#         [0.4746, 1.9985],
#         [0.4732, 1.9984],
#         [0.4722, 1.9978],
#         [0.4724, 1.9946],
#         [0.4726, 1.9915],
#         [0.4722, 1.9879],
#         [0.4724, 1.9853],
#         [0.4717, 1.9829],
#         [0.4717, 1.9794],
#         [0.4716, 1.9779],
#         [0.4708, 1.9760],
#         [0.4694, 1.9741],
#         [0.4680, 1.9731],
#         [0.4666, 1.9707],
#         [0.4645, 1.9681],
#         [0.4635, 1.9646],
#         [0.4626, 1.9628],
#         [0.4610, 1.9606],
#         [0.4597, 1.9582],
#         [0.4590, 1.9547],
#         [0.4589, 1.9512],
#         [0.4587, 1.9492],
#         [0.4585, 1.9479],
#         [0.4583, 1.9455],
#         [0.4591, 1.9440],
#         [0.4598, 1.9434],
#         [0.4602, 1.9431],
#         [0.4617, 1.9434],
#         [0.4633, 1.9435],
#         [0.4652, 1.9428],
#         [0.4667, 1.9422],
#         [0.4686, 1.9438],
#         [0.4701, 1.9460],
#         [0.4719, 1.9483],
#         [0.4741, 1.9493],
#         [0.4750, 1.9522],
#         [0.4756, 1.9537],
#         [0.4750, 1.9540],
#         [0.4757, 1.9527],
#         [0.4753, 1.9500],
#         [0.4752, 1.9492],
#         [0.4750, 1.9486],
#         [0.4745, 1.9503],
#         [0.4735, 1.9522],
#         [0.4743, 1.9519],
#         [0.4741, 1.9499],
#         [0.4743, 1.9489],
#         [0.4751, 1.9455],
#         [0.4775, 1.9427],
#         [0.4790, 1.9394],
#         [0.4798, 1.9351],
#         [0.4798, 1.9320],
#         [0.4798, 1.9313],
#         [0.4797, 1.9293],
#         [0.4799, 1.9275],
#         [0.4811, 1.9275],
#         [0.4824, 1.9280],
#         [0.4830, 1.9291],
#         [0.4826, 1.9315],
#         [0.4823, 1.9330],
#         [0.4819, 1.9355],
#         [0.4813, 1.9388],
#         [0.4809, 1.9420],
#         [0.4817, 1.9451],
#         [0.4822, 1.9496],
#         [0.4819, 1.9540],
#         [0.4808, 1.9564],
#         [0.4807, 1.9577],
#         [0.4798, 1.9584],
#         [0.4783, 1.9591],
#         [0.4771, 1.9603],
#         [0.4766, 1.9620],
#         [0.4753, 1.9652],
#         [0.4735, 1.9678],
#         [0.4715, 1.9704],
#         [0.4695, 1.9736],
#         [0.4674, 1.9780],
#         [0.4663, 1.9825],
#         [0.4649, 1.9888],
#         [0.4638, 1.9952],
#         [0.4638, 2.0002],
#         [0.4647, 2.0018],
#         [0.4644, 2.0043],
#         [0.4640, 2.0082],
#         [0.4628, 2.0103],
#         [0.4614, 2.0117],
#         [0.4597, 2.0123],
#         [0.4576, 2.0125],
#         [0.4549, 2.0158],
#         [0.4525, 2.0176],
#         [0.4507, 2.0179],
#         [0.4511, 2.0217],
#         [0.4522, 2.0223],
#         [0.4529, 2.0221],
#         [0.4536, 2.0218],
#         [0.4549, 2.0226],
#         [0.4560, 2.0237],
#         [0.4565, 2.0252],
#         [0.4562, 2.0267],
#         [0.4555, 2.0264],
#         [0.4550, 2.0265],
#         [0.4534, 2.0257],
#         [0.4517, 2.0239],
#         [0.4503, 2.0204],
#         [0.4492, 2.0179],
#         [0.4492, 2.0145],
#         [0.4497, 2.0094],
#         [0.4502, 2.0044],
#         [0.4500, 1.9993],
#         [0.4512, 1.9932],
#         [0.4519, 1.9868],
#         [0.4545, 1.9790],
#         [0.4575, 1.9700],
#         [0.4604, 1.9632],
#         [0.4636, 1.9553],
#         [0.4675, 1.9476],
#         [0.4711, 1.9413],
#         [0.4744, 1.9368],
#         [0.4782, 1.9313],
#         [0.4810, 1.9252],
#         [0.4834, 1.9199],
#         [0.4852, 1.9143],
#         [0.4879, 1.9092],
#         [0.4899, 1.9080],
#         [0.4911, 1.9070],
#         [0.4912, 1.9040]])

# %%
theta_sgd_momentum
# Out:
# tensor([[ 2.0000,  4.0000],
#         [ 1.8259,  3.9344],
#         [ 1.6734,  3.8711],
#         [ 1.3240,  3.8115],
#         [ 0.8143,  3.6980],
#         [ 0.1854,  3.5514],
#         [-0.3154,  3.3993],
#         [-0.7369,  3.2558],
#         [-0.9392,  3.0726],
#         [-1.0945,  2.8990],
#         [-0.8231,  2.6490],
#         [-0.3867,  2.4699],
#         [ 0.0239,  2.2901],
#         [ 0.5276,  2.1145],
#         [ 0.9705,  1.9557],
#         [ 1.3221,  1.8038],
#         [ 1.5292,  1.6432],
#         [ 1.6554,  1.5116],
#         [ 1.6543,  1.3618],
#         [ 1.5369,  1.2585],
#         [ 1.3300,  1.1960],
#         [ 1.0365,  1.1761],
#         [ 0.7643,  1.1621],
#         [ 0.4790,  1.1709],
#         [ 0.2589,  1.1891],
#         [ 0.0562,  1.2154],
#         [-0.1202,  1.2446],
#         [-0.2329,  1.2817],
#         [-0.3196,  1.3260],
#         [-0.2860,  1.3362],
#         [-0.2068,  1.3402],
#         [-0.0723,  1.3398],
#         [ 0.1949,  1.3743],
#         [ 0.4336,  1.4107],
#         [ 0.6412,  1.4542],
#         [ 0.8080,  1.5028],
#         [ 0.9251,  1.5452],
#         [ 0.9436,  1.5699],
#         [ 0.9208,  1.5911],
#         [ 0.8569,  1.6199],
#         [ 0.7452,  1.6349],
#         [ 0.6101,  1.6484],
#         [ 0.4816,  1.6622],
#         [ 0.3609,  1.6752],
#         [ 0.2905,  1.6974],
#         [ 0.2498,  1.7268],
#         [ 0.2777,  1.7686],
#         [ 0.3540,  1.8198],
#         [ 0.4354,  1.8658],
#         [ 0.5171,  1.9067],
#         [ 0.5859,  1.9483],
#         [ 0.6373,  1.9887],
#         [ 0.6261,  2.0275],
#         [ 0.6106,  2.0675],
#         [ 0.5649,  2.0966],
#         [ 0.5208,  2.1221],
#         [ 0.4730,  2.1449],
#         [ 0.4131,  2.1606],
#         [ 0.3503,  2.1717],
#         [ 0.3001,  2.1790],
#         [ 0.2674,  2.1803],
#         [ 0.2645,  2.1700],
#         [ 0.2957,  2.1593],
#         [ 0.3371,  2.1445],
#         [ 0.3921,  2.1310],
#         [ 0.4385,  2.1190],
#         [ 0.4864,  2.1080],
#         [ 0.5156,  2.0933],
#         [ 0.5360,  2.0763],
#         [ 0.5476,  2.0588],
#         [ 0.5339,  2.0424],
#         [ 0.5202,  2.0293],
#         [ 0.4867,  2.0116],
#         [ 0.4429,  1.9928],
#         [ 0.3950,  1.9731],
#         [ 0.3823,  1.9525],
#         [ 0.3951,  1.9284],
#         [ 0.4081,  1.9062],
#         [ 0.4323,  1.8882],
#         [ 0.4533,  1.8725],
#         [ 0.4829,  1.8578],
#         [ 0.5207,  1.8501],
#         [ 0.5547,  1.8491],
#         [ 0.5798,  1.8510],
#         [ 0.5899,  1.8575],
#         [ 0.5808,  1.8651],
#         [ 0.5685,  1.8790],
#         [ 0.5455,  1.8981],
#         [ 0.5063,  1.9131],
#         [ 0.4574,  1.9306],
#         [ 0.4120,  1.9486],
#         [ 0.3816,  1.9675],
#         [ 0.3544,  1.9840],
#         [ 0.3301,  1.9983],
#         [ 0.3074,  2.0124],
#         [ 0.2981,  2.0267],
#         [ 0.3287,  2.0388],
#         [ 0.3851,  2.0529],
#         [ 0.4615,  2.0578],
#         [ 0.5434,  2.0592],
#         [ 0.5969,  2.0616],
#         [ 0.6220,  2.0682],
#         [ 0.6448,  2.0753],
#         [ 0.6140,  2.0702],
#         [ 0.5649,  2.0615],
#         [ 0.5102,  2.0540],
#         [ 0.4523,  2.0462],
#         [ 0.3936,  2.0381],
#         [ 0.3418,  2.0311],
#         [ 0.3088,  2.0262],
#         [ 0.3137,  2.0197],
#         [ 0.3233,  2.0124],
#         [ 0.3732,  2.0088],
#         [ 0.4168,  2.0066],
#         [ 0.4605,  2.0040],
#         [ 0.4997,  2.0001],
#         [ 0.5266,  1.9990],
#         [ 0.5448,  1.9970],
#         [ 0.5537,  1.9941],
#         [ 0.5584,  1.9889],
#         [ 0.5586,  1.9863],
#         [ 0.5510,  1.9802],
#         [ 0.5265,  1.9765],
#         [ 0.4990,  1.9733],
#         [ 0.4697,  1.9755],
#         [ 0.4397,  1.9780],
#         [ 0.4356,  1.9819],
#         [ 0.4321,  1.9882],
#         [ 0.4401,  1.9915],
#         [ 0.4525,  1.9982],
#         [ 0.4622,  2.0038],
#         [ 0.4691,  2.0088],
#         [ 0.4788,  2.0161],
#         [ 0.4904,  2.0212],
#         [ 0.4923,  2.0228],
#         [ 0.4928,  2.0236],
#         [ 0.5027,  2.0229],
#         [ 0.4992,  2.0246],
#         [ 0.4819,  2.0231],
#         [ 0.4733,  2.0238],
#         [ 0.4601,  2.0261],
#         [ 0.4426,  2.0257],
#         [ 0.4295,  2.0257],
#         [ 0.4234,  2.0225],
#         [ 0.4153,  2.0191],
#         [ 0.4130,  2.0147],
#         [ 0.4250,  2.0108],
#         [ 0.4377,  2.0057],
#         [ 0.4623,  2.0048],
#         [ 0.4794,  2.0017],
#         [ 0.4920,  1.9975],
#         [ 0.5023,  1.9915],
#         [ 0.4994,  1.9838],
#         [ 0.4956,  1.9803],
#         [ 0.4880,  1.9777],
#         [ 0.4796,  1.9778],
#         [ 0.4616,  1.9783],
#         [ 0.4497,  1.9817],
#         [ 0.4371,  1.9862],
#         [ 0.4261,  1.9903],
#         [ 0.4252,  1.9977],
#         [ 0.4253,  2.0011],
#         [ 0.4267,  2.0020],
#         [ 0.4428,  2.0008],
#         [ 0.4588,  1.9992],
#         [ 0.4788,  1.9990],
#         [ 0.4964,  1.9979],
#         [ 0.5198,  2.0001],
#         [ 0.5399,  1.9966],
#         [ 0.5365,  1.9948],
#         [ 0.5222,  1.9996],
#         [ 0.5010,  2.0019],
#         [ 0.4720,  2.0017],
#         [ 0.4460,  2.0001],
#         [ 0.4244,  2.0027],
#         [ 0.4057,  2.0027],
#         [ 0.3926,  2.0049],
#         [ 0.3883,  2.0107],
#         [ 0.3937,  2.0168],
#         [ 0.4131,  2.0185],
#         [ 0.4312,  2.0223],
#         [ 0.4603,  2.0245],
#         [ 0.4884,  2.0270],
#         [ 0.5069,  2.0314],
#         [ 0.5141,  2.0346],
#         [ 0.5210,  2.0323],
#         [ 0.5215,  2.0271],
#         [ 0.5187,  2.0229],
#         [ 0.5073,  2.0203],
#         [ 0.4945,  2.0169],
#         [ 0.4744,  2.0108],
#         [ 0.4548,  2.0075],
#         [ 0.4282,  2.0030],
#         [ 0.4066,  2.0007],
#         [ 0.4001,  1.9934],
#         [ 0.4032,  1.9876],
#         [ 0.4254,  1.9848],
#         [ 0.4501,  1.9837],
#         [ 0.4701,  1.9829],
#         [ 0.4903,  1.9820],
#         [ 0.5028,  1.9833],
#         [ 0.5055,  1.9838],
#         [ 0.5151,  1.9835],
#         [ 0.5123,  1.9852],
#         [ 0.4993,  1.9852],
#         [ 0.4861,  1.9887],
#         [ 0.4781,  1.9941],
#         [ 0.4748,  1.9978],
#         [ 0.4712,  2.0036],
#         [ 0.4681,  2.0096],
#         [ 0.4556,  2.0138],
#         [ 0.4454,  2.0171],
#         [ 0.4351,  2.0184],
#         [ 0.4271,  2.0206],
#         [ 0.4187,  2.0217],
#         [ 0.4207,  2.0224],
#         [ 0.4446,  2.0200],
#         [ 0.4652,  2.0196],
#         [ 0.4830,  2.0180],
#         [ 0.4927,  2.0174],
#         [ 0.4974,  2.0161],
#         [ 0.4999,  2.0139],
#         [ 0.5028,  2.0142],
#         [ 0.5036,  2.0173],
#         [ 0.4954,  2.0221],
#         [ 0.4728,  2.0245],
#         [ 0.4461,  2.0275],
#         [ 0.4220,  2.0292],
#         [ 0.4055,  2.0274],
#         [ 0.3945,  2.0233],
#         [ 0.3882,  2.0195],
#         [ 0.4045,  2.0105],
#         [ 0.4180,  2.0017],
#         [ 0.4491,  1.9892],
#         [ 0.4832,  1.9769],
#         [ 0.5077,  1.9662],
#         [ 0.5304,  1.9600],
#         [ 0.5427,  1.9530],
#         [ 0.5490,  1.9503],
#         [ 0.5387,  1.9553],
#         [ 0.5280,  1.9630],
#         [ 0.5046,  1.9699],
#         [ 0.4849,  1.9756],
#         [ 0.4663,  1.9811],
#         [ 0.4453,  1.9872],
#         [ 0.4244,  1.9934],
#         [ 0.4046,  2.0003],
#         [ 0.3834,  2.0056],
#         [ 0.3693,  2.0080],
#         [ 0.3628,  2.0097],
#         [ 0.3637,  2.0108],
#         [ 0.3809,  2.0155],
#         [ 0.4011,  2.0181],
#         [ 0.4356,  2.0157],
#         [ 0.4694,  2.0138],
#         [ 0.4928,  2.0132],
#         [ 0.5156,  2.0120],
#         [ 0.5322,  2.0110],
#         [ 0.5422,  2.0082],
#         [ 0.5493,  2.0043],
#         [ 0.5399,  2.0042],
#         [ 0.5278,  2.0060],
#         [ 0.5083,  2.0049],
#         [ 0.4851,  2.0045],
#         [ 0.4606,  1.9988],
#         [ 0.4348,  1.9943],
#         [ 0.4115,  1.9909],
#         [ 0.3979,  1.9901],
#         [ 0.3827,  1.9931],
#         [ 0.3844,  1.9929],
#         [ 0.4016,  1.9890],
#         [ 0.4131,  1.9896],
#         [ 0.4306,  1.9909],
#         [ 0.4483,  1.9911],
#         [ 0.4623,  1.9907],
#         [ 0.4767,  1.9895],
#         [ 0.5014,  1.9851],
#         [ 0.5122,  1.9826],
#         [ 0.5184,  1.9836],
#         [ 0.5268,  1.9844],
#         [ 0.5307,  1.9881],
#         [ 0.5063,  1.9878],
#         [ 0.4901,  1.9840],
#         [ 0.4781,  1.9786],
#         [ 0.4674,  1.9756],
#         [ 0.4514,  1.9727],
#         [ 0.4475,  1.9682],
#         [ 0.4459,  1.9634],
#         [ 0.4577,  1.9629],
#         [ 0.4759,  1.9600],
#         [ 0.4854,  1.9552],
#         [ 0.4915,  1.9530],
#         [ 0.4904,  1.9505],
#         [ 0.4926,  1.9485],
#         [ 0.4900,  1.9448],
#         [ 0.4892,  1.9389],
#         [ 0.4779,  1.9355],
#         [ 0.4611,  1.9326],
#         [ 0.4399,  1.9284],
#         [ 0.4221,  1.9244],
#         [ 0.4145,  1.9192],
#         [ 0.4168,  1.9119],
#         [ 0.4245,  1.9052],
#         [ 0.4439,  1.8979],
#         [ 0.4797,  1.8963],
#         [ 0.5153,  1.8915],
#         [ 0.5395,  1.8876],
#         [ 0.5522,  1.8858],
#         [ 0.5489,  1.8885],
#         [ 0.5455,  1.8912],
#         [ 0.5359,  1.8994],
#         [ 0.5246,  1.9074],
#         [ 0.4898,  1.9173],
#         [ 0.4575,  1.9278],
#         [ 0.4311,  1.9348],
#         [ 0.4043,  1.9422],
#         [ 0.3808,  1.9491],
#         [ 0.3615,  1.9565],
#         [ 0.3550,  1.9676],
#         [ 0.3523,  1.9777],
#         [ 0.3622,  1.9823],
#         [ 0.3896,  1.9865],
#         [ 0.4303,  1.9961],
#         [ 0.4867,  2.0039],
#         [ 0.5330,  2.0107],
#         [ 0.5586,  2.0196],
#         [ 0.5669,  2.0261],
#         [ 0.5639,  2.0261],
#         [ 0.5282,  2.0189],
#         [ 0.4927,  2.0137],
#         [ 0.4572,  2.0083],
#         [ 0.4255,  2.0016],
#         [ 0.3965,  1.9955],
#         [ 0.3988,  1.9833],
#         [ 0.4130,  1.9760],
#         [ 0.4245,  1.9694],
#         [ 0.4323,  1.9661],
#         [ 0.4481,  1.9653],
#         [ 0.4605,  1.9650],
#         [ 0.4884,  1.9620],
#         [ 0.5051,  1.9576],
#         [ 0.5255,  1.9593],
#         [ 0.5436,  1.9605],
#         [ 0.5581,  1.9580],
#         [ 0.5428,  1.9561],
#         [ 0.5269,  1.9568],
#         [ 0.5066,  1.9573],
#         [ 0.4848,  1.9579],
#         [ 0.4654,  1.9589],
#         [ 0.4416,  1.9620],
#         [ 0.4366,  1.9661],
#         [ 0.4320,  1.9724],
#         [ 0.4355,  1.9820],
#         [ 0.4422,  1.9930],
#         [ 0.4510,  2.0031],
#         [ 0.4655,  2.0095],
#         [ 0.4715,  2.0161],
#         [ 0.4808,  2.0207],
#         [ 0.4896,  2.0219],
#         [ 0.4845,  2.0244],
#         [ 0.4876,  2.0258],
#         [ 0.4902,  2.0278],
#         [ 0.4879,  2.0297],
#         [ 0.4830,  2.0317],
#         [ 0.4683,  2.0345],
#         [ 0.4484,  2.0343],
#         [ 0.4368,  2.0318],
#         [ 0.4272,  2.0279],
#         [ 0.4271,  2.0239],
#         [ 0.4274,  2.0221],
#         [ 0.4303,  2.0193],
#         [ 0.4434,  2.0134],
#         [ 0.4570,  2.0067],
#         [ 0.4736,  2.0021],
#         [ 0.4874,  1.9954],
#         [ 0.5002,  1.9852],
#         [ 0.5026,  1.9742],
#         [ 0.5066,  1.9646],
#         [ 0.5020,  1.9566],
#         [ 0.4892,  1.9483],
#         [ 0.4774,  1.9427],
#         [ 0.4670,  1.9358],
#         [ 0.4485,  1.9347],
#         [ 0.4350,  1.9353],
#         [ 0.4405,  1.9321],
#         [ 0.4451,  1.9311],
#         [ 0.4684,  1.9298],
#         [ 0.4958,  1.9273],
#         [ 0.5239,  1.9243],
#         [ 0.5458,  1.9218],
#         [ 0.5635,  1.9209],
#         [ 0.5680,  1.9234],
#         [ 0.5438,  1.9304],
#         [ 0.5167,  1.9372],
#         [ 0.4854,  1.9497],
#         [ 0.4617,  1.9605],
#         [ 0.4420,  1.9737],
#         [ 0.4526,  1.9853],
#         [ 0.4637,  1.9960],
#         [ 0.4694,  2.0097]])

# %%
X[np.floor(np.random.rand(5)*M).astype(int)] @ theta_sgd_momentum[1,:] -y[np.floor(np.random.rand(5)*M).astype(int)].reshape(1,-1)
# Out:
# tensor([[-0.0335, -7.2565,  8.0602,  2.0773,  6.3758]])

# %%
a = torch.Tensor([2,4])
j = np.floor(np.random.rand(10)*50).astype(int)
xj = X[j,:]
yj = y[j,:].reshape(1,-1)
print(a.shape)
print(xj.shape)
print(yj.shape)
# Out:
# torch.Size([2])
# torch.Size([10, 2])
# torch.Size([1, 10])

# %%
yPred = xj @ a.reshape(-1,1)
print(yPred.shape)
# Out:
# torch.Size([10, 1])

# %%
dw = torch.sum((yPred - yj.t()) * xj, dim = 1)
print(dw.shape)
# Out:
# torch.Size([10])

# %%
yPred - yj.t()
# Out:
# tensor([[-0.3721],
#         [ 0.5728],
#         [-3.1694],
#         [ 6.3705],
#         [-1.6183],
#         [-2.1371],
#         [-1.5071],
#         [-2.1371],
#         [ 7.0860],
#         [ 0.3894]])

# %%
xj
# Out:
# tensor([[-1.6135,  1.0000],
#         [-1.1095,  1.0000],
#         [-3.5155,  1.0000],
#         [ 3.2505,  1.0000],
#         [-2.5848,  1.0000],
#         [-2.6639,  1.0000],
#         [-2.3879,  1.0000],
#         [-2.6639,  1.0000],
#         [ 3.5792,  1.0000],
#         [-1.0994,  1.0000]])

# %%
(yPred - yj.t()) * xj
# Out:
# tensor([[ 0.6003, -0.3721],
#         [-0.6355,  0.5728],
#         [11.1420, -3.1694],
#         [20.7071,  6.3705],
#         [ 4.1830, -1.6183],
#         [ 5.6931, -2.1371],
#         [ 3.5987, -1.5071],
#         [ 5.6931, -2.1371],
#         [25.3623,  7.0860],
#         [-0.4281,  0.3894]])
